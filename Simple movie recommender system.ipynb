# %% [markdown]
# Goal: Build a simple recommender system to recommend the best movies to users

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
pd.set_option('display.max_columns', None)
metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
metadata.shape
# Out:
# (45466, 24)

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
metadata.rename(columns = {'vote_count' : 'V_ratings_count', 'vote_average' : 'R_average_ratings'}, inplace=True)

# %%
metadata.describe()
# Out:
#             revenue       runtime  R_average_ratings  V_ratings_count
# count  4.546000e+04  45203.000000       45460.000000     45460.000000
# mean   1.120935e+07     94.128199           5.618207       109.897338
# std    6.433225e+07     38.407810           1.924216       491.310374
# min    0.000000e+00      0.000000           0.000000         0.000000
# 25%    0.000000e+00     85.000000           5.000000         3.000000
# 50%    0.000000e+00     95.000000           6.000000        10.000000
# 75%    0.000000e+00    107.000000           6.800000        34.000000
# max    2.787965e+09   1256.000000          10.000000     14075.000000

# %%
metadata['release_date'].unique()
# Out:
# array(['1995-10-30', '1995-12-15', '1995-12-22', ..., '1904-03-05',
#        '1991-05-13', '1917-10-21'], dtype=object)

# %%
metadata.count()
# Out:
# adult                    45466
# belongs_to_collection     4494
# budget                   45466
# genres                   45466
# homepage                  7782
# id                       45466
# imdb_id                  45449
# original_language        45455
# original_title           45466
# overview                 44512
# popularity               45461
# poster_path              45080
# production_companies     45463
# production_countries     45463
# release_date             45379
# revenue                  45460
# runtime                  45203
# spoken_languages         45460
# status                   45379
# tagline                  20412
# title                    45460
# video                    45460
# R_average_ratings        45460
# V_ratings_count          45460
# dtype: int64

# %%
# Calculate the mean of the average rating
C = metadata['R_average_ratings'].mean()
print(C)
# Out:
# 5.618207215134185

# %% [markdown]
# From the output above you can observe that the average rating of a movie on a scale of 10 is around 5.618

# %%
# Let's calculate the minimun number of ratings required to be in the chart (M)
M = metadata['V_ratings_count'].quantile(0.90)
print(M)
# Out:
# 160.0

# %% [markdown]
# M which is 160 is the number of counts a movie has that we will allow/recommend

# %%
# Now allow movies that are equal to or greater than 160(M) ratings count
# Keep the relevant movie
q_movies = metadata.copy().loc[metadata['V_ratings_count'] >= M]
q_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 8  False                                                NaN  35000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 8  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
q_movies.shape
# Out:
# (4555, 24)

# %%
# Function to compute the weighted rating of each movie

def weighted_ratings(dataframe, M=M, C=C):
    V = dataframe['V_ratings_count']
    R = dataframe['R_average_ratings']
    
    return (V/(V+M) * R) + (M/(M+V) * C)

q_movies['Score'] = q_movies.apply(weighted_ratings, axis=1)
# Show the top movies
q_movies = q_movies.sort_values('Score', ascending=False)
q_movies.reset_index(drop=True, inplace=True)
q_movies.head(5)
# Out:
#    adult                              belongs_to_collection     budget  \
# 0  False                                                NaN   25000000
# 1  False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 2  False                                                NaN   13200000
# 3  False  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# 4  False                                                NaN   63000000
#
#                                               genres  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4                      [{'id': 18, 'name': 'Drama'}]
#
#                                        homepage     id    imdb_id  \
# 0                                           NaN    278  tt0111161
# 1                  http://www.thegodfather.com/    238  tt0068646
# ...

# %%
recommend_movies = q_movies[['title', 'V_ratings_count', 'R_average_ratings', 'Score']]
recommend_movies.head(22)
# Out:
#                               title  V_ratings_count  R_average_ratings  \
# 0          The Shawshank Redemption           8358.0                8.5
# 1                     The Godfather           6024.0                8.5
# 2       Dilwale Dulhania Le Jayenge            661.0                9.1
# 3                   The Dark Knight          12269.0                8.3
# 4                        Fight Club           9678.0                8.3
# 5                      Pulp Fiction           8670.0                8.3
# 6                  Schindler's List           4436.0                8.3
# 7                          Whiplash           4376.0                8.3
# 8                     Spirited Away           3968.0                8.3
# 9                 Life Is Beautiful           3643.0                8.3
# 10           The Godfather: Part II           3418.0                8.3
# 11  One Flew Over the Cuckoo's Nest           3001.0                8.3
# ...
